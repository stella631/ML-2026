# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# 파일 경로를 지정합니다.
file = 'skin_irritation.xlsx'

# 엑셀 파일을 데이터프레임으로 읽어옵니다.
# io: 문자열 경로 등 유효한 경로를 전달합니다 [1].
# sheet_name: 불러올 시트 이름을 지정합니다 (예: "Sheet1") [2].
# usecols: 머신러닝에 사용할 특정 컬럼만 리스트나 문자열로 지정하여 추출합니다 [3].
df = pd.read_excel(file)

# 불러온 데이터의 상위 5개 행을 확인합니다.
print(df)
# Out:
#                   ICE version:  \
# 0                File created:
# 1                          NaN
# 2                       Column
# 3                    Record_ID
# 4                    Data_Type
# 5             Formulation_Name
# 6               Formulation_ID
# 7                Chemical_Name
# 8                        CASRN
# 9                       DTXSID
# 10   Percent_Active_Ingredient
# 11               Concentration
# 12         Concentration_Units
# 13                     Mixture
# 14                       Assay
# 15                    Endpoint
# 16                    Response
# 17               Response_Unit
# 18                   Reference
# 19                      SMILES
# 20              Preferred_Name
# 21                    Synonyms
# 22                 URL_CompTox
# 23                    URL_CEBS
# 24                     Species
# 25             Reported_Strain
# 26                      Strain
# 27                         Sex
# 28                         NaN
# ...

# %%
df = pd.read_excel(io=file, sheet_name='Data_invivo')

# 불러온 데이터의 상위 5개 행을 확인합니다.
print(df)
# Out:
#                         Record_ID Data_Type Formulation_ID  \
# 0       skin_irritation_invivo_18   In Vivo            NaN
# 1       skin_irritation_invivo_83   In Vivo            NaN
# 2       skin_irritation_invivo_80   In Vivo            NaN
# 3      skin_irritation_invivo_822   In Vivo          MIX82
# 4      skin_irritation_invivo_719   In Vivo         MIX380
# ...                           ...       ...            ...
# 2053  skin_irritation_invivo_1222   In Vivo         MIX242
# 2054   skin_irritation_invivo_966   In Vivo         MIX242
# 2055   skin_irritation_invivo_824   In Vivo          MIX13
# 2056   skin_irritation_invivo_816   In Vivo          MIX13
# 2057   skin_irritation_invivo_217   In Vivo          MIX13
#
#                      Formulation_Name  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                           Captan 4L
# 4        Raid Roach & Ant Killer Plus
# ...

# %%
# 'column_name' 부분에 개수를 확인하고 싶은 실제 컬럼 이름을 문자열로 넣으세요.
counts = df['Endpoint'].value_counts()

# 결과 출력
print(counts)
# Out:
# Endpoint
# EPA classification            1799
# Qualitative classification      90
# Positive reaction               90
# GHS classification              79
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt


# 1. 도화지 크기 설정 (가로 10, 세로 6)
plt.figure(figsize=(10, 6))

# 히스토그램 그리기 (numeric_column_name에 실제 컬럼명 입력)
plt.hist(filtered_df['Response'], bins=10, color='blue', alpha=0.7)

# 2. x축 숫자 45도 회전하기

plt.xticks(rotation=45)

plt.title('Histogram of Positive Reaction')
plt.xlabel('Value')
plt.ylabel('Frequency')

# 3. 레이아웃 겹치지 않게 자동 조정
plt.tight_layout()

# 그래프 출력
plt.show()
